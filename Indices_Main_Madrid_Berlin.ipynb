# %%
import sys
sys.path.append("/home/scorpio/ngsild-pythonclient-initial_ngsild_client/src/")
import ast
import json
from ngsildclient.client import Client
from ngsildclient.entity import Entity
import csv
import time
from datetime import datetime
import pandas as pd 
import numpy as np
from geojson import Point

num_rows_batch_publish=5000 # number of objects to be batch published to Scorpio

client_obj = Client("localhost", "9090") # connect to scorpio

def publish(entity):
    response = client_obj.temporal_create(entity)
    #print(response)
    if response['status_code']> 400:
        print("ERROR: Cannot publish data from the NGSI client.")
    return response

# %%
import pandas as pd

df_list_berlin=[]

for i in range(5):
    df = pd.read_pickle("./data/index_berlin_" + str(i) + ".pkl")
    df_list_berlin.append(df)
    
df_list_madrid=[]
for i in range(6):
    df = pd.read_pickle("./data/index_madrid_" + str(i) + ".pkl")
    df_list_madrid.append(df)
    
    
df_list_berlin[1]
# Out:
#                                         related_sensors  current_annual_mean  \
# 1     [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.083333
# 2     [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            15.291667
# 3     [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            16.263889
# 4     [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            16.718750
# 5     [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            15.633333
# ...                                                 ...                  ...
# 4375  [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.229068
# 4376  [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.209724
# 4377  [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.212830
# 4378  [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.183071
# 4379  [urn:ngsi-ld:AirQualityObserved:BerlinPM10:ID:...            19.240866
#
#                                              index_type  hexagon_id  \
# 1     urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...         147
# 2     urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...         147
# 3     urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...         147
# 4     urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...         147
# 5     urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...         147
# ...                                                 ...         ...
# 4375  urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...           5
# 4376  urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...           5
# 4377  urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...           5
# 4378  urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...           5
# 4379  urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubInd...           5
#
#              date_time                                           geometry
# 1     01.02.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.47036...
# 2     01.03.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.47036...
# 3     01.04.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.47036...
# 4     01.05.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.47036...
# 5     01.06.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.47036...
# ...                ...                                                ...
# 4375  31.05.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.40993...
# 4376  31.07.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.40993...
# 4377  31.08.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.40993...
# 4378  31.10.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.40993...
# 4379  31.12.2022 00:00  {'type': 'Polygon', 'coordinates': [[[13.40993...
#
# [4368 rows x 6 columns]

# %%
madrid_gdf_property_list=["NO2", "O3", "PM10",  "PM2_5", "SO2", "CO"]

entity_type_prefix_madrid = 'CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean'
madrid_index_list=[]
for g in gdf_property_list:
    madrid_index_list.append( 'urn:ngsi-ld:' + entity_type_prefix_madrid + ':' + g)

madrid_index_list
# Out:
# ['urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:CO',
#  'urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:PM10',
#  'urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:PM2_5',
#  'urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:NO2',
#  'urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:O3']

# %%
berlin_gdf_property_list=["CO","PM10",  "PM2_5",  "NO2", "O3"]

entity_type_prefix_berlin = 'CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean'
berlin_index_list=[]
for g in gdf_property_list:
    berlin_index_list.append( 'urn:ngsi-ld:' + entity_type_prefix_berlin + ':' + g)

berlin_index_list
# Out:
# ['urn:ngsi-ld:CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean:CO',
#  'urn:ngsi-ld:CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean:PM10',
#  'urn:ngsi-ld:CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean:PM2_5',
#  'urn:ngsi-ld:CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean:NO2',
#  'urn:ngsi-ld:CityLiveabilityIndex:Berlin:Index:AirQualityAnnualMean:O3']

# %%
existing_entity_id_list = {}
def save_main_indices(df, entity_type, entity_ID, location, date_format, sub_index_prefix):
    counter= 0
    example_flag=True

    
    date_time_list= df.date_time.unique()
    
    for date_time in date_time_list:
        
        entity_obj = Entity(entity_type, entity_ID, ["https://raw.githubusercontent.com/smart-data-models/data-models/master/context.jsonld"]) # (re-)initialize the entity

        
        date_time_data = df[df['date_time'] == date_time]
        if(len(date_time_data) ==0):
            continue
        related_hexagon_id_list = date_time_data.hexagon_id.unique()
        if(len(related_hexagon_id_list)):
            print("Warning: There is no related hexagon for the general index. This should not happen")
        index_value = date_time_data['current_annual_mean'].mean()
        
        # add properties
        # geoproperty
        entity_obj.add_geoprop("location", location, observedAt= datetime.strptime(str(date_time_data.iloc[0].date_time), date_format))
        # value
        entity_obj.add_prop('current_annual_mean', index_value, observedAt= datetime.strptime(str(date_time_data.iloc[0].date_time), date_format))
        entity_obj.add_prop('data', index_value, observedAt= datetime.strptime(str(date_time_data.iloc[0].date_time), date_format))
        # relations --> related hexagons
        for hexagon_id in related_hexagon_id_list:
            related_id =  sub_index_prefix  + str(hexagon_id)
            entity_obj.add_rel('providedBy', related_id, observedAt= datetime.strptime(str(date_time_data.iloc[0].date_time), date_format))
            publish(entity_obj.to_dict()) # publish the entity
        if example_flag:
            print('INFO: Example data from the dataset to be published - as an example on how data looks.')
            print(entity_obj)
            example_flag=False

        print('Info: Dataset is published successfully with entity ID: ' + entity_ID)

# %%
madrid_location = Point(( -3.703790,40.416775))
berlin_location = Point((13.404954, 52.520008))
sub_index_madrid_prefix = 'urn:ngsi-ld:CityLiveabilityIndex:Madrid:SubIndex:AirQualityAnnualMean:' 
sub_index_berlin_prefix = 'urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubIndex:AirQualityAnnualMean:'


    
for index, df in enumerate(df_list_madrid):
    save_main_indices(df, entity_type_prefix_madrid, madrid_index_list[index], madrid_location, '%Y-%m-%d %H:%M:%S', sub_index_madrid_prefix +   madrid_gdf_property_list[index]  + ':Hexagon:')

for index, df in enumerate(df_list_berlin):
    save_main_indices(df, entity_type_prefix_berlin, berlin_index_list[index], berlin_location, '%d.%m.%Y %H:%M' ,sub_index_berlin_prefix + berlin_gdf_property_list[index] + ':Hexagon:')
# Out:
# Warning: There is no related hexagon for the general index. This should not happen
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:CO', 'type': 'CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean', '@context': ['https://raw.githubusercontent.com/smart-data-models/data-models/master/context.jsonld'], 'location': {'type': 'Property', 'value': {"coordinates": [-3.70379, 40.416775], "type": "Point"}, 'observedAt': '2022-01-02T00:00:00Z'}, 'current_annual_mean': {'type': 'Property', 'value': 45.212890625, 'observedAt': '2022-01-02T00:00:00Z'}, 'data': {'type': 'Property', 'value': 45.212890625, 'observedAt': '2022-01-02T00:00:00Z'}, 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:CityLiveabilityIndex:Madrid:SubIndex:AirQualityAnnualMean:NO2:Hexagon:6', 'observedAt': '2022-01-02T00:00:00Z'}}
# Info: Dataset is published successfully with entity ID: urn:ngsi-ld:CityLiveabilityIndex:Madrid:Index:AirQualityAnnualMean:CO
# Warning: There is no related hexagon for the general index. This should not happen
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ERROR: Cannot publish data from the NGSI client.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.8/_collections_abc.py:666, in Mapping.__contains__(self, key)
#     665 try:
# --> 666     self[key]
#     667 except KeyError:
#
# File /usr/lib/python3.8/os.py:675, in _Environ.__getitem__(self, key)
#     673 except KeyError:
#     674     # raise KeyError with the original key value
# --> 675     raise KeyError(key) from None
#     676 return self.decodevalue(value)
#
# KeyError: 'REQUEST_METHOD'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 9
#       4 sub_index_berlin_prefix = 'urn:ngsi-ld:CityLiveabilityIndex:Berlin:SubIndex:AirQualityAnnualMean:'
#       8 for index, df in enumerate(df_list_madrid):
# ----> 9     save_main_indices(df, entity_type_prefix_madrid, madrid_index_list[index], madrid_location, '%Y-%m-%d %H:%M:%S', sub_index_madrid_prefix +   madrid_gdf_property_list[index]  + ':Hexagon:')
#      11 for index, df in enumerate(df_list_berlin):
#      12     save_main_indices(df, entity_type_prefix_berlin, berlin_index_list[index], berlin_location, '%d.%m.%Y %H:%M' ,sub_index_berlin_prefix + berlin_gdf_property_list[index] + ':Hexagon:')
#
# Cell In[72], line 32, in save_main_indices(df, entity_type, entity_ID, location, date_format, sub_index_prefix)
#      30     related_id =  sub_index_prefix  + str(hexagon_id)
#      31     entity_obj.add_rel('providedBy', related_id, observedAt= datetime.strptime(str(date_time_data.iloc[0].date_time), date_format))
# ---> 32     publish(entity_obj.to_dict()) # publish the entity
#      33 if example_flag:
#      34     print('INFO: Example data from the dataset to be published - as an example on how data looks.')
#
# Cell In[63], line 19, in publish(entity)
#      18 def publish(entity):
# ---> 19     response = client_obj.temporal_create(entity)
#      20     #print(response)
#      21     if response['status_code']> 400:
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/client.py:225, in Client.temporal_create(self, entity, context, NGSILD_Tenant, NGSILD_Path, *options)
#     200 def temporal_create(
#     201     self,
#     202     entity,
#    (...)
#     206     *options
#     207 ):
#     208     """
#     209     Description
#     210     -----------------------------
#    (...)
#     223     -----------------------------------
#     224     """
# --> 225     return Temporal.temporal_create(self.base_url, entity, context=context, ngsild_tenant=NGSILD_Tenant,
#     226                                     ngsild_path=NGSILD_Path)
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/helper/temporal.py:31, in Temporal.temporal_create(cls, base_url, entity, context, ngsild_tenant, ngsild_path, **options)
#      29 url = base_url+constants.NGSILD_TEMPORAL_ENDPOINT
#      30 headers = u.add_header(context, ngsild_tenant, ngsild_path)
# ---> 31 return Rest.post(entity, url, headers)
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/rest/rest.py:28, in Rest.post(cls, body, url, headers, **kargs)
#      20 @classmethod
#      21 def post(
#      22         cls,
#    (...)
#      26         **kargs
#      27         ):
# ---> 28     response = requests.post(url = url, data = json.dumps(body), headers = headers)
#      29     return status.handle_result(response.status_code, response.text)
#
# File ~/.local/lib/python3.8/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:577, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     573 prep = self.prepare_request(req)
#     575 proxies = proxies or {}
# --> 577 settings = self.merge_environment_settings(
#     578     prep.url, proxies, stream, verify, cert
#     579 )
#     581 # Send the request.
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:759, in Session.merge_environment_settings(self, url, proxies, stream, verify, cert)
#     756 if self.trust_env:
#     757     # Set environment's proxies.
#     758     no_proxy = proxies.get("no_proxy") if proxies is not None else None
# --> 759     env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     760     for (k, v) in env_proxies.items():
#     761         proxies.setdefault(k, v)
#
# File ~/.local/lib/python3.8/site-packages/requests/utils.py:833, in get_environ_proxies(url, no_proxy)
#     831     return {}
#     832 else:
# --> 833     return getproxies()
#
# File /usr/lib/python3.8/urllib/request.py:2514, in getproxies_environment()
#    2509         proxies[name[:-6]] = value
#    2510 # CVE-2016-1000110 - If we are running as CGI script, forget HTTP_PROXY
#    2511 # (non-all-lowercase) as it may be set from the web server by a "Proxy:"
#    2512 # header from the client
#    2513 # If "proxy" is lowercase, it will still be used thanks to the next block
# -> 2514 if 'REQUEST_METHOD' in os.environ:
#    2515     proxies.pop('http', None)
#    2516 for name, value in os.environ.items():
#
# File /usr/lib/python3.8/_collections_abc.py:666, in Mapping.__contains__(self, key)
#     664 def __contains__(self, key):
#     665     try:
# --> 666         self[key]
#     667     except KeyError:
#     668         return False
#
# KeyboardInterrupt:
