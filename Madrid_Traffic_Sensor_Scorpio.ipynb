# %%
import sys
sys.path.append("/home/scorpio/ngsild-pythonclient-initial_ngsild_client/src/")

import ast
import json
from ngsildclient.client import Client
from ngsildclient.entity import Entity
import csv
import time
from datetime import datetime
import pandas as pd 
import numpy as np
from geojson.geometry import Point, Polygon, MultiLineString

client_obj = Client("localhost", "9090") # connect to scorpio

def publish(entity):
    response = client_obj.temporal_create(entity)
    #print(response)
    if response['status_code']> 400:
        print("ERROR: Cannot publish data from the NGSI client.")
    return response

# %%
num_rows_batch_publish=5000 # number of objects to be batch published to Scorpio

# %% [markdown]
# # Notes:
# Consider every hexagon as an entity, and sensor data as properties

# %%
import pandas as pd
import geopandas as gpd

from geojson.geometry import Point, Polygon, MultiLineString

# %%
# !ls ./../cgarrido/madrid_data/traffic/
# Out:
# 10-2022.csv			   gdf_proc_traffic_month_12.pkl
# 11-2022.csv			   gdf_proc_traffic_month_1.pkl
# 1-2022.csv			   gdf_proc_traffic_month_2.pkl
# 12-2022.csv			   gdf_proc_traffic_month_3.pkl
# 2-2022.csv			   gdf_proc_traffic_month_4.pkl
# 3-2022.csv			   gdf_proc_traffic_month_5.pkl
# 4-2022.csv			   gdf_proc_traffic_month_6.pkl
# 5-2022.csv			   gdf_proc_traffic_month_7.pkl
# 6-2022.csv			   gdf_proc_traffic_month_8.pkl
# 7-2022.csv			   gdf_proc_traffic_month_9.pkl
# 8-2022.csv			   gdf_raw_traffic_month_10.pkl
# 9-2022.csv			   gdf_raw_traffic_month10.pkl
# gdf_aggr_traffic_m30_month_10.pkl  gdf_raw_traffic_month_11.pkl
# gdf_aggr_traffic_m30_month_11.pkl  gdf_raw_traffic_month11.pkl
# gdf_aggr_traffic_m30_month_12.pkl  gdf_raw_traffic_month_12.pkl
# gdf_aggr_traffic_m30_month_1.pkl   gdf_raw_traffic_month12.pkl
# gdf_aggr_traffic_m30_month_2.pkl   gdf_raw_traffic_month_1.pkl
# gdf_aggr_traffic_m30_month_3.pkl   gdf_raw_traffic_month_2.pkl
# gdf_aggr_traffic_m30_month_4.pkl   gdf_raw_traffic_month_3.pkl
# gdf_aggr_traffic_m30_month_5.pkl   gdf_raw_traffic_month_4.pkl
# gdf_aggr_traffic_m30_month_6.pkl   gdf_raw_traffic_month_5.pkl
# gdf_aggr_traffic_m30_month_7.pkl   gdf_raw_traffic_month_6.pkl
# gdf_aggr_traffic_m30_month_8.pkl   gdf_raw_traffic_month_7.pkl
# gdf_aggr_traffic_m30_month_9.pkl   gdf_raw_traffic_month_8.pkl
# gdf_aggr_traffic_urb_month_10.pkl  gdf_raw_traffic_month_9.pkl
# gdf_aggr_traffic_urb_month_11.pkl  gdf_raw_traffic.pkl
# gdf_aggr_traffic_urb_month_12.pkl  gfd_aggr_traffic_urb.pkl
# gdf_aggr_traffic_urb_month_1.pkl   pmed_ubicacion_10-2022.xlsx
# gdf_aggr_traffic_urb_month_2.pkl   pmed_ubicacion_11-2022.xlsx
# gdf_aggr_traffic_urb_month_3.pkl   pmed_ubicacion_1-2022.xlsx
# gdf_aggr_traffic_urb_month_4.pkl   pmed_ubicacion_12-2022.xlsx
# gdf_aggr_traffic_urb_month_5.pkl   pmed_ubicacion_2-2022.xlsx
# gdf_aggr_traffic_urb_month_6.pkl   pmed_ubicacion_3-2022.xlsx
# gdf_aggr_traffic_urb_month_7.pkl   pmed_ubicacion_4-2022.xlsx
# gdf_aggr_traffic_urb_month_8.pkl   pmed_ubicacion_5-2022.xlsx
# gdf_aggr_traffic_urb_month_9.pkl   pmed_ubicacion_6-2022.xlsx
# gdf_aggr_traffic_urb.pkl	   pmed_ubicacion_7-2022.xlsx
# gdf_proc_traffic_month_10.pkl	   pmed_ubicacion_8-2022.xlsx
# gdf_proc_traffic_month_11.pkl	   pmed_ubicacion_9-2022.xlsx

# %%
traffic_sensor_df = pd.read_pickle('./../cgarrido/madrid_data/traffic/gdf_proc_traffic_month_1.pkl')

# %%
traffic_sensor_df
# Out:
#                id  hexagon_id  hexagon_x  hexagon_y            datetime  year  \
# 0          1001.0          17          2          2 2022-01-01 00:00:00  2022
# 1          1001.0          17          2          2 2022-01-21 14:30:00  2022
# 2          1001.0          17          2          2 2022-01-21 14:45:00  2022
# 3          1001.0          17          2          2 2022-01-21 15:00:00  2022
# 4          1001.0          17          2          2 2022-01-21 15:15:00  2022
# ...           ...         ...        ...        ...                 ...   ...
# 11370684  10920.0          12         -1          1 2022-01-21 14:30:00  2022
# 11370685  10920.0          12         -1          1 2022-01-21 14:15:00  2022
# 11370686  10920.0          12         -1          1 2022-01-21 14:00:00  2022
# 11370687  10920.0          12         -1          1 2022-01-21 16:15:00  2022
# 11370688  10920.0          12         -1          1 2022-01-31 23:30:00  2022
#
#           month  day  hour  minute  weekday  type  intensity  occupation  \
# 0             1    1     0       0        5   0.0      408.0         1.0
# 1             1   21    14      30        4   0.0     2712.0         7.0
# 2             1   21    14      45        4   0.0     3432.0        11.0
# 3             1   21    15       0        4   0.0     3648.0        11.0
# 4             1   21    15      15        4   0.0     3384.0        10.0
# ...         ...  ...   ...     ...      ...   ...        ...         ...
# 11370684      1   21    14      30        4   1.0      189.0         4.0
# 11370685      1   21    14      15        4   1.0      224.0         7.0
# 11370686      1   21    14       0        4   1.0      135.0         5.0
# 11370687      1   21    16      15        4   1.0      169.0         7.0
# 11370688      1   31    23      30        0   1.0       53.0         2.0
#
#           load  avg_speed                         geometry        lat  \
# 0          0.0       61.0  POINT (-416422.368 4925662.875)  40.416629
# 1          0.0       59.0  POINT (-416422.368 4925662.875)  40.416629
# 2          0.0       59.0  POINT (-416422.368 4925662.875)  40.416629
# 3          0.0       61.0  POINT (-416422.368 4925662.875)  40.416629
# 4          0.0       60.0  POINT (-416422.368 4925662.875)  40.416629
# ...        ...        ...                              ...        ...
# 11370684  12.0        0.0  POINT (-408709.672 4921384.081)  40.385890
# 11370685  10.0        0.0  POINT (-408709.672 4921384.081)  40.385890
# 11370686   9.0        0.0  POINT (-408709.672 4921384.081)  40.385890
# 11370687  10.0        0.0  POINT (-408709.672 4921384.081)  40.385890
# 11370688   3.0        0.0  POINT (-408709.672 4921384.081)  40.385890
#
#                lon
# 0        -3.730246
# 1        -3.730246
# 2        -3.730246
# 3        -3.730246
# 4        -3.730246
# ...            ...
# 11370684 -3.664442
# 11370685 -3.664442
# 11370686 -3.664442
# 11370687 -3.664442
# 11370688 -3.664442
#
# [11370689 rows x 19 columns]

# %%
#Air qality not required - kept for reference
#gdf_NO2 = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_NO2.pkl')
#gdf_O3 = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_O3.pkl')
#gdf_PM10 = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_PM10.pkl')
#gdf_PM2_5 = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_PM2.5.pkl')
#gdf_SO2 = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_SO2.pkl')
#gdf_CO = pd.read_pickle('./../cgarrido/madrid_data/air_pollution/gdf_CO.pkl')

# %%
#gdf_list= [gdf_PM2_5,gdf_NO2, gdf_O3, gdf_PM10,  gdf_SO2, gdf_CO]
gdf_property_list=["ttype","intensity","occupation","load","avg_speed"]
entity_id_prefix =  "urn:ngsi-ld:TrafficObserved:Madrid:"
entity_type = 'TrafficObserved'

# %%
from pyproj import Transformer

transformer = Transformer.from_crs("EPSG:3857", "EPSG:4326") # transform geometry to lat/lon
poly = traffic_sensor_df['geometry']
#traffic_sensor_df['lat'], traffic_sensor_df['lon'] = transformer.transform(poly.centroid.x,poly.centroid.y) 
#for g in gdf_list:
#    poly = g['geometry']
#    g['lat'] ,  g['lon'] =  transformer.transform(poly.centroid.x,poly.centroid.y)

# %%
traffic_sensor_df.groupby(by = ['id','lat', 'lon']).count()
# Out:
#                              hexagon_id  hexagon_x  hexagon_y  datetime  year  \
# id      lat       lon
# 1001.0  40.409729 -3.740786        2976       2976       2976      2976  2976
# 1002.0  40.408030 -3.743760        2976       2976       2976      2976  2976
# 1003.0  40.406824 -3.746834        2976       2976       2976      2976  2976
# 1006.0  40.411894 -3.736324        2976       2976       2976      2976  2976
# 1012.0  40.419861 -3.722097        2975       2975       2975      2975  2975
# ...                                 ...        ...        ...       ...   ...
# 10915.0 40.375395 -3.655853        2976       2976       2976      2976  2976
# 10917.0 40.379500 -3.671742        2976       2976       2976      2976  2976
# 10918.0 40.379595 -3.670096        2976       2976       2976      2976  2976
# 10919.0 40.380650 -3.670044        2976       2976       2976      2976  2976
# 10920.0 40.380456 -3.671501        2976       2976       2976      2976  2976
#
#                              month   day  hour  minute  weekday  type  \
# id      lat       lon
# 1001.0  40.409729 -3.740786   2976  2976  2976    2976     2976  2976
# 1002.0  40.408030 -3.743760   2976  2976  2976    2976     2976  2976
# 1003.0  40.406824 -3.746834   2976  2976  2976    2976     2976  2976
# 1006.0  40.411894 -3.736324   2976  2976  2976    2976     2976  2976
# 1012.0  40.419861 -3.722097   2975  2975  2975    2975     2975  2975
# ...                            ...   ...   ...     ...      ...   ...
# 10915.0 40.375395 -3.655853   2976  2976  2976    2976     2976  2976
# 10917.0 40.379500 -3.671742   2976  2976  2976    2976     2976  2976
# 10918.0 40.379595 -3.670096   2976  2976  2976    2976     2976  2976
# 10919.0 40.380650 -3.670044   2976  2976  2976    2976     2976  2976
# 10920.0 40.380456 -3.671501   2976  2976  2976    2976     2976  2976
#
#                              intensity  occupation  load  avg_speed  geometry
# id      lat       lon
# 1001.0  40.409729 -3.740786       2976        2976  2976       2976      2976
# 1002.0  40.408030 -3.743760       2976        2976  2976       2976      2976
# 1003.0  40.406824 -3.746834       2976        2976  2976       2976      2976
# 1006.0  40.411894 -3.736324       2976        2976  2976       2976      2976
# 1012.0  40.419861 -3.722097       2975        2975  2975       2975      2975
# ...                                ...         ...   ...        ...       ...
# 10915.0 40.375395 -3.655853       2976        2976  2976       2976      2976
# 10917.0 40.379500 -3.671742       2976        2976  2976       2976      2976
# 10918.0 40.379595 -3.670096       2976        2976  2976       2976      2976
# 10919.0 40.380650 -3.670044       2976        2976  2976       2976      2976
# 10920.0 40.380456 -3.671501       2976        2976  2976       2976      2976
#
# [3825 rows x 16 columns]

# %%
for mnth in range(1,13):
    ingestion_starttime= time.perf_counter() 
    traffic_sensor_df = pd.read_pickle('./../cgarrido/madrid_data/traffic/gdf_proc_traffic_month_'+str(mnth)+'.pkl')
    poly = traffic_sensor_df['geometry']
    traffic_sensor_df['lat'], traffic_sensor_df['lon'] = transformer.transform(poly.centroid.x,poly.centroid.y) 
    example_flag=True
    uniqueStationIDs= traffic_sensor_df['id'].unique()
    dataset_length= len(traffic_sensor_df)
    feature_list= traffic_sensor_df.columns.tolist()
    sensor_name = 'Traffic_month_'+str(mnth)
    for u in uniqueStationIDs:
        station_tmp_gdf = traffic_sensor_df[traffic_sensor_df['id'] == u] 
        entity_obj = Entity(entity_type, entity_id_prefix + sensor_name + ":ID:" + str(int(u)) )
        counter=0
        for index, row in station_tmp_gdf.iterrows():
            lat=0
            lon=0
            if counter %num_rows_batch_publish==0: # create a new clean entity everytime a batch is completed/published to avoid duplicate push of same values 
                entity_obj = Entity(entity_type, entity_id_prefix + sensor_name + ":ID:" + str(int(u))) # (re-)initialize the entity
            for f in range(len(feature_list)):
                if feature_list[f] == 'lat': lat = row[f]
                if feature_list[f] == 'lon': lon=row[f]
                if lat !=0 and lon !=0: # both values are obtained for location, add the location attribute 
                    location_value = Point((lat, lon))
                    entity_obj.add_geoprop("location", location_value, observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S')) # MAKE THIS A POINT (SIVA EXAMPLE)
                elif feature_list[f] in ['intensity','occupation','load','avg_speed']:
                    entity_obj.add_prop(feature_list[f], str(row[f]) , observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S'))                 
                #elif(feature_list[f] not in ['datetime','type']):
                #    entity_obj.add_prop(feature_list[f], str(row[f]) , observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S'))                 
            if example_flag:
                print('INFO: Example data from the dataset to be published - as an example on how data looks.')
                print(entity_obj)
                example_flag=False

            if (counter %num_rows_batch_publish==0 or counter == len(station_tmp_gdf)-1) and  counter!=0: # publish the batch data for entity to scorpio as the rows fulfill the number of rows needed for a batch, or the dataset has come to the end
                publish(entity_obj.to_dict()) # publish the entity
                print('Published one batch')
            counter+=1 
    print("... published data for dataset: " +  sensor_name)

    ingestion_endtime= time.perf_counter() 
    print('Info: Dataset is published successfully' 

    + ' --- It took ' + str(ingestion_endtime -ingestion_starttime) + ' seconds to publish the dataset with length ' + str(dataset_length))
# Out:
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:TrafficObserved:Madrid:Traffic_month_1:ID:1001', 'type': 'TrafficObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'intensity': {'type': 'Property', 'value': '408.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'occupation': {'type': 'Property', 'value': '1.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'load': {'type': 'Property', 'value': '0.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'avg_speed': {'type': 'Property', 'value': '61.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.409729, -3.740786], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# ...
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch
# Published one batch

# %% [markdown]
# 1- Check context and add context (smart data model link) to the @context tag
#
# 2- Geometry: Change geometry to location. Location is a geoproperty. Give the point values as "coordinates". Keep the observedat on every property.
#
# 3- Convert coordinates to lon/lat
#
# 4- Add no2, so2 as property (not as a separate entity). One entity per hexagon
# .
# 5- Add district instead of hexagons

# %%
example_flag=False
for property_index, tmp_gdf in enumerate(gdf_list): # for each dataset 
    ingestion_starttime= time.perf_counter() 
    example_flag=True
    sensor_name =gdf_property_list[property_index]
    if(sensor_name == 'PM2.5'):
        sensor_name = "PM2_5"
    counter =0
    uniqueStationIDs= tmp_gdf['station_id'].unique()
    dataset_length= len(tmp_gdf)
    feature_list= tmp_gdf.columns.tolist()

    for u in uniqueStationIDs:
        station_tmp_gdf = tmp_gdf[tmp_gdf['station_id'] == u] # take data coming only from this station ID (this sensor entity)
        entity_obj = Entity(entity_type, entity_id_prefix + sensor_name + ":ID:" + str(int(u)) ) # initialize the entity for the new station
        print(entity_id_prefix + str(sensor_name) + ":" + str(int(u)))
        counter=0 # start pushing data about this entity

        for index, row in station_tmp_gdf.iterrows():

            lat=0
            lon=0
            if counter %num_rows_batch_publish==0: # create a new clean entity everytime a batch is completed/published to avoid duplicate push of same values 
                entity_obj = Entity(entity_type, entity_id_prefix + sensor_name + ":ID:" + str(int(u))) # (re-)initialize the entity
            for f in range(len(feature_list)):
                if feature_list[f] == 'lat': lat = row[f]
                if feature_list[f] == 'lon': lon=row[f]
                if lat !=0 and lon !=0: # both values are obtained for location, add the location attribute 
                    location_value = Point((lat, lon))
                    entity_obj.add_geoprop("location", location_value, observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S')) # MAKE THIS A POINT (SIVA EXAMPLE)
                elif feature_list[f] == 'data':
                    entity_obj.add_prop(sensor_name, str(row[f]) , observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S'))                 
                elif(feature_list[f] not in ['datetime','type']):
                    entity_obj.add_prop(feature_list[f], str(row[f]) , observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S'))                 
            if example_flag:
                print('INFO: Example data from the dataset to be published - as an example on how data looks.')
                print(entity_obj)
                example_flag=False

            if (counter %num_rows_batch_publish==0 or counter == len(station_tmp_gdf)-1) and  counter!=0: # publish the batch data for entity to scorpio as the rows fulfill the number of rows needed for a batch, or the dataset has come to the end
                publish(entity_obj.to_dict()) # publish the entity
            counter+=1 
    print("... published data for dataset: " +  sensor_name)

    ingestion_endtime= time.perf_counter() 
    print('Info: Dataset is published successfully' 
        
          + ' --- It took ' + str(ingestion_endtime -ingestion_starttime) + ' seconds to publish the dataset with length ' + str(dataset_length))
# Out:
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:24
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:ID:24', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '24.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-417152.48156697437 4927070.647350454)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '36', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '3', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '3', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '646.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'PM2_5': {'type': 'Property', 'value': '31.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4193577', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.419358, -3.747344], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:48
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:47
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:57
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:56
# urn:ngsi-ld:AirQualityObserved:Madrid:PM2_5:50
# ... published data for dataset: PM2_5
# Info: Dataset is published successfully --- It took 312.4241430540569 seconds to publish the dataset with length 210240
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:8
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:NO2:ID:8', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '8.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-409913.5197960258 4927391.691444065)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '672.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'NO2': {'type': 'Property', 'value': '35.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4215533', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.421553, -3.682316], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:38
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:60
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:18
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:24
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:59
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:48
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:47
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:56
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:40
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:55
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:27
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:17
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:36
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:58
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:35
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:49
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:50
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:57
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:11
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:54
# urn:ngsi-ld:AirQualityObserved:Madrid:NO2:39
# ... published data for dataset: NO2
# Info: Dataset is published successfully --- It took 1583.1842359530274 seconds to publish the dataset with length 770880
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:8
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:O3:ID:8', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '8.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-409913.5197960258 4927391.691444065)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '672.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'O3': {'type': 'Property', 'value': '18.39', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4215533', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.421553, -3.682316], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:24
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:27
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:35
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:60
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:49
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:39
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:17
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:18
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:58
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:59
# urn:ngsi-ld:AirQualityObserved:Madrid:O3:54
# ... published data for dataset: O3
# Info: Dataset is published successfully --- It took 616.1642001869623 seconds to publish the dataset with length 420480
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:24
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:PM10:ID:24', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '24.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-417152.48156697437 4927070.647350454)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '36', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '3', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '3', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '646.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'PM10': {'type': 'Property', 'value': '36.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4193577', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.419358, -3.747344], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:55
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:50
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:57
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:48
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:47
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:60
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:40
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:36
# urn:ngsi-ld:AirQualityObserved:Madrid:PM10:56
# ... published data for dataset: PM10
# Info: Dataset is published successfully --- It took 494.1150276460685 seconds to publish the dataset with length 350400
# urn:ngsi-ld:AirQualityObserved:Madrid:SO2:8
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:SO2:ID:8', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '8.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-409913.5197960258 4927391.691444065)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '672.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'SO2': {'type': 'Property', 'value': '4.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4215533', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.421553, -3.682316], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:SO2:36
# urn:ngsi-ld:AirQualityObserved:Madrid:SO2:35
# ... published data for dataset: SO2
# Info: Dataset is published successfully --- It took 145.88323436304927 seconds to publish the dataset with length 105120
# urn:ngsi-ld:AirQualityObserved:Madrid:CO:8
# INFO: Example data from the dataset to be published - as an example on how data looks.
# {'id': 'urn:ngsi-ld:AirQualityObserved:Madrid:CO:ID:8', 'type': 'AirQualityObserved', '@context': ['https://uri.etsi.org/ngsi-ld/v1/ngsi-ld-core-context.jsonld'], 'station_id': {'type': 'Property', 'value': '8.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'geometry': {'type': 'Property', 'value': 'POINT (-409913.5197960258 4927391.691444065)', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_id': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_x': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'hexagon_y': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'altitude': {'type': 'Property', 'value': '672.0', 'observedAt': '2022-01-01T00:00:00Z'}, 'year': {'type': 'Property', 'value': '2022', 'observedAt': '2022-01-01T00:00:00Z'}, 'month': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'day': {'type': 'Property', 'value': '1', 'observedAt': '2022-01-01T00:00:00Z'}, 'hour': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'minute': {'type': 'Property', 'value': '0', 'observedAt': '2022-01-01T00:00:00Z'}, 'weekday': {'type': 'Property', 'value': '5', 'observedAt': '2022-01-01T00:00:00Z'}, 'CO': {'type': 'Property', 'value': '0.4', 'observedAt': '2022-01-01T00:00:00Z'}, 'lat': {'type': 'Property', 'value': '40.4215533', 'observedAt': '2022-01-01T00:00:00Z'}, 'location': {'type': 'GeoProperty', 'value': {"coordinates": [40.421553, -3.682316], "type": "Point"}, 'observedAt': '2022-01-01T00:00:00Z'}}
# urn:ngsi-ld:AirQualityObserved:Madrid:CO:56
# urn:ngsi-ld:AirQualityObserved:Madrid:CO:35
# ... published data for dataset: CO
# Info: Dataset is published successfully --- It took 150.0524859589059 seconds to publish the dataset with length 105120

# %% [markdown]
# # Query temporal entity from Scorpio and get it as Pandas

# %%
client_obj = Client("localhost", "9090")
pandas_data= client_obj.get_temporal("urn:ngsi-ld:AirQualityObserved:Madrid:Hexagon:0", entityType="AirQualityObserved", pandasSeries=True, attribute="value")
print(pandas_data)
print(type(pandas_data))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 client_obj = Client("localhost", "9090")
# ----> 2 pandas_data= client_obj.get_temporal("urn:ngsi-ld:AirQualityObserved:Madrid:Hexagon:0", entityType="AirQualityObserved", pandasSeries=True, attribute="value")
#       3 print(pandas_data)
#       4 print(type(pandas_data))
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/client.py:271, in Client.get_temporal(self, entityID, entityType, pandasSeries, attribute, index, context, NGSILD_Tenant, NGSILD_Path, **options)
#     268 if entityID == None and entityType == None:
#     269     raise Exception("Id or Type must be required")
# --> 271 return Temporal.temporal_query(self.base_url, options, ids=entityID, entity_type=entityType, pandas_series=pandasSeries, attribute=attribute, index=index, context=context, ngsild_tenant=NGSILD_Tenant, ngsild_path=NGSILD_Path)
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/helper/temporal.py:95, in Temporal.temporal_query(cls, base_url, param, ids, entity_type, context, ngsild_tenant, ngsild_path, pandas_series, attribute, index)
#      93 if pandas_series is False:
#      94     return historical_data
# ---> 95 return cls.get_pandas_series(historical_data, pandas_series, attribute, index)
#
# File ~/ngsild-pythonclient-initial_ngsild_client/src/ngsildclient/helper/temporal.py:109, in Temporal.get_pandas_series(cls, historical_data, pandas_series, attribute, index)
#     107             pandas_list.append(result)
#     108     return pandas_list
# --> 109 return cls.series_to_pd_series(historical_data[attribute], index)
#
# KeyError: 'value'

# %% [markdown]
# ## BACKUP CODE
#
# import time
#
#
# for entity_index, tmp_gdf in enumerate(gdf_list): # for each dataset
#
#     feature_list= tmp_gdf.columns.tolist()
#     for index, row in tmp_gdf.iterrows():
#         if index %num_rows_batch_publish==0: # create a new clean entity everytime a batch is completed/published to avoid duplicate push of same values
#             entity_obj = Entity(entity_type_list[entity_index], entity_id_list[entity_index]) # (re-)initialize the entity
#         for i in range(len(feature_list)):
#             if feature_list[i] =='type': feature_list[i] ='road_type' # quick fix for the error of "type" conflicting with ngsi-ld "type"
#             if(feature_list[i] not in ['datetime','type']):
#                 entity_obj.add_prop(feature_list[i], str(row[i]) , observedAt= datetime.strptime(str(row.datetime), '%Y-%m-%d %H:%M:%S'))
#         if index == 0:
#             print('INFO: Initial row of the dataset to be published - as an example on how data looks.')
#             print(entity_obj)
#
#         #ingestion_starttime= time.perf_counter()
#         temp_objects.append(entity_obj)
#         if (index %num_rows_batch_publish==0 or index == len(tmp_gdf)-1) and  index!=0: # publish the batch data for entity to scorpio as the rows fulfill the number of rows needed for a batch, or the dataset has come to the end
#             publish(entity_obj.to_dict()) # publish the entity
#
#         f(index%10000 ==0):
#             print("... published data count: " +  str(index))
#
#         #print('Info: Ingestion took ' + str(ingestion_endtime -ingestion_starttime) + ' seconds for ' +  str(num_rows_batch_publish) + ' objects')
#
#     print('Info: Dataset is published successfully with entity ID: ' + str(entity_id_list[entity_index]))
